# %%
import cv2
import numpy as np
import pytesseract 
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
img_ori = cv2.imread('E:/work/bmw.jpg')
plt.figure(figsize=(12,10))
plt.imshow(img_ori,cmap='gray')

# %%
img_ori = cv2.imread('E:/work/bmw.jpg',cv2. IMREAD_GRAYSCALE)
plt.figure(figsize=(12,10))
plt.imshow(img_ori,cmap='gray')
plt.show()

# %%
img = cv2.imread('E:/work/bmw.jpg',cv2. IMREAD_GRAYSCALE)
newimg = np.zeros(img.shape,th.dtype)
alpha = 3
for y in range(img.shape[0]):
    for x in range(img.shape[1]):
        newimg[y,x] = np.clip(alpha*img[y,x],0,255)
newimg = cv2.medianBlur(newimg,5)
newimg = cv2.adaptiveThreshold(newimg,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)
            
plt.figure(figsize=(12,10))
plt.imshow(newimg,cmap='gray')


plt.show()
